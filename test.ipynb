# %% [markdown]
# **Тестирование**
#
# Тестовый абзац
#
# | таблица |   |
# |---|---|
# | 1  | 2  |
# | 3  | 4  |

# %%
for x in range(1, 5):
    print(f'{x} * {x} = {x * x}')
# Out:
# 1 * 1 = 1
# 2 * 2 = 4
# 3 * 3 = 9
# 4 * 4 = 16

# %% [markdown]
# Тест тест тест
